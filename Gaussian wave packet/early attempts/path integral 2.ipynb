# %%
import numpy as np
from numpy import linalg
import matplotlib.pyplot as plt
import time

# %% [markdown]
# # free particle with initial state as a Gaussian wave packet

# %% [markdown]
# ## 1

# %%
T = 0.1
method = 2
if method == 1:
    Nscale = 50
    L = int(Nscale*200*T)
    N = int(T * Nscale * 1 + 1)
    M = int(L * Nscale / 2)
else:
    Nscale = 0
    L = 1500
    M = 30*L
    N = 10
x = np.linspace(-L, L, M + 1)
dx = 2*L/M
dt = T/(N + 1)
#---------------------------------------------------------
#time_seconds = np.log(N) * M**3 * 1.8e-10
time_seconds = N * M**2 * 1.6e-7
hours = int(time_seconds // 3600)
minutes = int((time_seconds % 3600) // 60)
seconds = int(time_seconds % 60)
print(f'(T='+f'{T}'+', L='+f'{L}'+', M='+f'{M}'+', N='+f'{N}'+', (Nscale='+f'{Nscale}'+'))')
print(f"Estimated time: {hours}h {minutes}min {seconds}s")
# Out:
# (T=0.1, L=1500, M=45000, N=10, (Nscale=0))
# Estimated time: 0h 54min 0s

# %%
print(f'(T='+f'{T}'+', L='+f'{L}'+', M='+f'{M}'+', N='+f'{N}'+', (Nscale='+f'{Nscale}'+'))')
k0 = 1
m = 1
psi_0 = (2 / np.pi)**(1/4) * np.exp(- x**2 + 1j * k0 * x)
'''
K = []
for xi in x:
    Ki = []
    for xj in x:
        Kij = (m / (2 * np.pi * 1j * dt))**0.5 * np.exp(1j * (m / 2 * (xi - xj)**2/dt))
        Ki.append(Kij)
    K.append(Ki)
K = np.array(K)
'''
# Assuming x is a NumPy array
x = np.asarray(x)
X_i, X_j = np.meshgrid(x, x, indexing='ij')
K = (m / (2 * np.pi * 1j * dt))**0.5 * np.exp(1j * (m / 2 * (X_i - X_j)**2 / dt))
#print(f'condition(K) = {np.linalg.cond(K)}')

run_time_start = time.time()
#KpowerN = K
#for i in range(N):
#    KpowerN = KpowerN @ K # K^{N + 1}
#KpowerN = np.linalg.matrix_power(K, N+1)
psi_final = psi_0
for i in range(N+1):
    psi_final = dx * K @ psi_final
run_time_end = time.time()

#si_final = dx**(N + 1) * KpowerN @ psi_0

#print(f't/complexity = {(run_time_end-run_time_start)/(np.log(N) * M**3)}')
print(f't/complexity = {(run_time_end-run_time_start)/(N * M**2)}')
np.save('data/(T='+f'{T}'+', L='+f'{L}'+', M='+f'{M}'+', N='+f'{N}'+', (Nscale='+f'{Nscale}'+')) - psi_final.npy', psi_final)
# Out:
# (T=0.1, L=1500, M=45000, N=10, (Nscale=0))
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[65], line 17
#      15 # Assuming x is a NumPy array
#      16 x = np.asarray(x)
# ---> 17 X_i, X_j = np.meshgrid(x, x, indexing='ij')
#      18 K = (m / (2 * np.pi * 1j * dt))**0.5 * np.exp(1j * (m / 2 * (X_i - X_j)**2 / dt))
#      19 #print(f'condition(K) = {np.linalg.cond(K)}')
#
# File c:\Users\siyang\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:5263, in meshgrid(copy, sparse, indexing, *xi)
#    5260     output = np.broadcast_arrays(*output, subok=True)
#    5262 if copy:
# -> 5263     output = tuple(x.copy() for x in output)
#    5265 return output
#
# File c:\Users\siyang\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:5263, in <genexpr>(.0)
#    5260     output = np.broadcast_arrays(*output, subok=True)
#    5262 if copy:
# -> 5263     output = tuple(x.copy() for x in output)
#    5265 return output
#
# MemoryError: Unable to allocate 15.1 GiB for an array with shape (45001, 45001) and data type float64

# %% [markdown]
# ## float32 data type

# %%
T = 0.1
method = 2
if method == 1:
    Nscale = 50
    L = int(Nscale*200*T)
    N = int(T * Nscale * 1 + 1)
    M = int(L * Nscale / 2)
else:
    Nscale = 0
    L = 1000
    M = 30*L
    N = 10
x = np.linspace(-L, L, M + 1).astype(np.float32)
dx = np.float32(2*L/M)
dt = np.float32(T/(N + 1))
#---------------------------------------------------------
#time_seconds = np.log(N) * M**3 * 1.8e-10
time_seconds = N * M**2 * 1.6e-7
hours = int(time_seconds // 3600)
minutes = int((time_seconds % 3600) // 60)
seconds = int(time_seconds % 60)
print(f'(T='+f'{T}'+', L='+f'{L}'+', M='+f'{M}'+', N='+f'{N}'+', (Nscale='+f'{Nscale}'+'))')
print(f"Estimated time: {hours}h {minutes}min {seconds}s")
# Out:
# (T=0.1, L=1000, M=30000, N=10, (Nscale=0))
# Estimated time: 0h 24min 0s

# %%
print(f'(T='+f'{T}'+', L='+f'{L}'+', M='+f'{M}'+', N='+f'{N}'+', (Nscale='+f'{Nscale}'+'))')
t1_start = time.time()
k0 = 1
m = 1
psi_0 = ((2 / np.pi)**(1/4) * np.exp(- x**2 + 1j * k0 * x)).astype(np.complex64)

# Assuming x is a NumPy array
x = np.asarray(x)
X_i, X_j = np.meshgrid(x, x, indexing='ij')
K = ((m / (2 * np.pi * 1j * dt))**0.5 * np.exp(1j * (m / 2 * (X_i - X_j)**2 / dt))).astype(np.complex64)

run_time_start = time.time()
print(f't1 = {run_time_start - t1_start:.2f}s')

psi_final = psi_0
for i in range(N+1):
    psi_final = dx * K @ psi_final
psi_final = psi_final.astype(np.complex64)

run_time_end = time.time()

print(f't2 = {(run_time_end - run_time_start)/60:.2f}min')
print(f't/complexity = {(run_time_end-run_time_start)/(N * M**2)}')
np.save('data/(T='+f'{T}'+', L='+f'{L}'+', M='+f'{M}'+', N='+f'{N}'+', (Nscale='+f'{Nscale}'+')) - psi_final.npy', psi_final)
# Out:
# (T=0.1, L=1000, M=30000, N=10, (Nscale=0))
# t1 = 88.93s
# t2 = 1.82min
# t/complexity = 1.2150814135869343e-08

# %% [markdown]
# ## plot

# %%
load = 0
if load == 0:
    psi_final = np.load('data/(T='+f'{T}'+', L='+f'{L}'+', M='+f'{M}'+', N='+f'{N}'+', (Nscale='+f'{Nscale}'+')) - psi_final.npy')
else: # load == 1
    psi_final = np.load('data/(T=0.1, L=300.0, M=9001, N=4, (Nscale=30)) - psi_final.npy')
    T=0.1
    L=300
    M=9001-1
    N=4

rho_final = (psi_final.real)**2 + (psi_final.imag)**2
xmax = 2
x = np.linspace(-L, L, M+1)
dx = 2*L/M
rho_renormalized = []
for i in range(len(psi_final)):
    if x[i] + dx > - xmax and x[i] - dx < xmax:
        rho_renormalized.append(rho_final[i])
    else:
        rho_renormalized.append(0)
rho_renormalized = np.array(rho_renormalized)
A = sum(rho_renormalized) * dx
rho_renormalized = rho_renormalized / A
fig, ax = plt.subplots(figsize=(4,3))
ax.plot(x, rho_renormalized)
psi_analytically = (2/np.pi)**(1/4) * np.sqrt(m/(m + 1j * 2 * T)) * np.exp(m/(m + 1j * 2 * T) * (- x**2 + 1j * k0 * x) - 1j * k0**2 / (2 * (m + 1j * 2 * T)) * T)
rho_analytically = (psi_analytically.real)**2 + (psi_analytically.imag)**2
ax.plot(x, rho_analytically, linestyle='--', linewidth=0.5, color='black', label='analytical result')
ax.axvline(x=0, linestyle='-', linewidth=0.5, color='black')
ax.set_title('$L = '+f'{L}'+', M = '+f'{M}'+', N = '+f'{N}$')
ax.set_xlabel('$x$')
ax.set_ylabel('$\\rho(T = '+f'{T}'+', x)$')
ax.set_xlim(-xmax, xmax)
ax.set_ylim(0, 1)
ax.legend()
plt.tight_layout()
plt.savefig('numerical path integral (normalized) of a free particle with initial state as a Gaussian wave packet and T='+f'{T}'+' (L='+f'{L}'+', M='+f'{M}'+', N='+f'{N}'+').pdf', format='pdf')
plt.show()

Ascale = int(np.log(rho_final[int(M/2)])/np.log(10))
print(f'A = {(rho_final[int(M/2)] / 10**Ascale):1f} * 10^({Ascale})')
# Out:
# A = 3.578565 * 10^(36)

# %%
psi_final = np.load('data/(T='+f'{T}'+', L='+f'{L}'+', M='+f'{M}'+', N='+f'{N}'+', (Nscale='+f'{Nscale}'+')) - psi_final.npy')
rho_final = (psi_final.real)**2 + (psi_final.imag)**2
xmax = 2
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].plot(x, rho_final)
axes[0].set_xlim(-xmax, xmax)
#axes[0].set_ylim(-1e100, 1e131)
axes[0].axvline(x=0, linestyle='-', linewidth=0.5, color='black')
axes[0].axhline(y=0, linestyle='-', linewidth=0.5, color='black')
axes[0].set_title('$L = '+f'{L}'+', M = '+f'{M}'+', N = '+f'{N}$')
axes[0].set_xlabel('$x$')
axes[0].set_ylabel('$\\rho(T = '+f'{T}'+', x)$')

psi_analytically = (2/np.pi)**(1/4) * np.sqrt(m/(m + 1j * 2 * T)) * np.exp(m/(m + 1j * 2 * T) * (- x**2 + 1j * k0 * x) - 1j * k0**2 / (2 * (m + 1j * 2 * T)) * T)
rho_analytically = (psi_analytically.real)**2 + (psi_analytically.imag)**2
axes[1].plot(x, rho_analytically)
axes[1].set_xlim(-xmax, xmax)
axes[1].set_ylim(-0.1, 1)
axes[1].axvline(x=0, linestyle='-', linewidth=0.5, color='black')
axes[1].axhline(y=0, linestyle='-', linewidth=0.5, color='black')
axes[1].set_title('analytical result')
axes[1].set_xlabel('$x$')
axes[1].set_ylabel('$\\rho(T = '+f'{T}'+', x)$')

plt.tight_layout()
#plt.savefig('numerical path integral of a free particle with initial state as a Gaussian wave packet and T='+f'{T}'+' (L='+f'{L}'+', M='+f'{M}'+', N='+f'{N}'+').pdf', format='pdf')
plt.show()
print(f'Nscale = {Nscale}')
# Out:
# Nscale = 50

# %% [markdown]
# # harmonic oscilator

# %%
L = 50
T = 0.01
N = 40
M = 1000
x = np.linspace(-L, L, M)
dx = 2*L/(M-1)
dt = T/(N - 1 + 1)

m = 1
omega = 1
k0 = 1
psi_0 = (2 / np.pi)**(1/4) * np.exp(- x**2 + 1j * k0 * x)
K = []
for xi in x:
    Ki = []
    for xj in x:
        Kij = (m / (2 * np.pi * 1j * dt))**0.5 * np.exp(1j * (m / 2 * (xi - xj)**2/dt - dt * m/2 * omega**2 * xi**2))
        Ki.append(Kij)
    K.append(Ki)
K = np.array(K)
KpowerN = K
for i in range(N):
    KpowerN = KpowerN @ K # K^{N + 1}
psi_final = dx**(N + 1) * KpowerN @ psi_0

# %%
rho_final = (psi_final.real)**2 + (psi_final.imag)**2
fig, ax = plt.subplots(figsize=(4, 3))
ax.plot(x, rho_final)
ax.set_xlim(-L/10, L/10)
ax.axhline(y=0, linestyle='-', linewidth=0.5, color='black')
plt.show()

# %% [markdown]
# # (almost-)infinite square well

# %%
L = 50
T = 0.01
N = 5
M = 1000
x = np.linspace(-L, L, M)
dx = 2*L/(M-1)
dt = T/(N - 1 + 1)

m = 1
def V(x):
    if x > 10 or x < - 10:
        return 100000
    else:
        return 0
#k0 = 1
psi_0 = []
for xi in x:
    if xi < 1/2 and xi > - 1/2:
        psi_0.append(1)
    else:
        psi_0.append(0)
psi_0 = np.array(psi_0)

K = []
for xi in x:
    Ki = []
    for xj in x:
        Kij = (m / (2 * np.pi * 1j * dt))**0.5 * np.exp(1j * (m / 2 * (xi - xj)**2/dt - dt * V(xi)))
        Ki.append(Kij)
    K.append(Ki)
K = np.array(K)
KpowerN = K
for i in range(N):
    KpowerN = KpowerN @ K # K^{N + 1}
psi_final = dx**(N + 1) * KpowerN @ psi_0

# %%
rho_final = (psi_final.real)**2 + (psi_final.imag)**2
fig, ax = plt.subplots(figsize=(4, 3))
ax.plot(x, rho_final)
ax.set_xlim(-15, 15)
ax.axhline(y=0, linestyle='-', linewidth=0.5, color='black')
ax.axvline(x=1/2, linestyle='--', linewidth=0.5, color='black')
ax.axvline(x=-1/2, linestyle='--', linewidth=0.5, color='black')
plt.show()
